# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_hospitaldischarge=pd.read_excel('/content/Cardiac_Outcomes.xlsx', sheet_name='Hospitalization_Discharge')

# %%
df_hospitaldischarge
# Out:
#       inpatient_number DestinationDischarge admission_ward admission_way  \
# 0               857781                 Home     Cardiology  NonEmergency
# 1               743087                 Home     Cardiology  NonEmergency
# 2               866418                 Home     Cardiology  NonEmergency
# 3               775928                 Home     Cardiology     Emergency
# 4               810128                 Home     Cardiology  NonEmergency
# ...                ...                  ...            ...           ...
# 2003            740689   HealthcareFacility    GeneralWard     Emergency
# 2004            734280   HealthcareFacility    GeneralWard     Emergency
# 2005            781004   HealthcareFacility     Cardiology     Emergency
# 2006            744870              Unknown     Cardiology  NonEmergency
# 2007            791864                 Home     Cardiology     Emergency
#
#      discharge_department  visit_times respiratory_support oxygen_inhalation  \
# ...

# %%
df_CardiacComplications=pd.read_excel('/content/Cardiac_Outcomes.xlsx', sheet_name='CardiacComplications')

# %%
df_CardiacComplications
# Out:
#       inpatient_number  NYHA_cardiac_function_classification  Killip_grade  \
# 0               857781                                     3             3
# 1               743087                                     3             1
# 2               866418                                     2             2
# 3               775928                                     3             2
# 4               810128                                     3             2
# ...                ...                                   ...           ...
# 2003            740689                                     4             1
# 2004            734280                                     4             2
# 2005            781004                                     3             1
# 2006            744870                                     4             4
# 2007            791864                                     3             1
#
#       myocardial_infarction  congestive_heart_failure  \
# ...

# %%
df_Responsivenes=pd.read_excel('/content/Cardiac_Outcomes.xlsx', sheet_name='Responsivenes')

# %%
df_Responsivenes
# Out:
#       inpatient_number  eye_opening  verbal_response  movement  consciousness  \
# 0               857781            4                5         6          Clear
# 1               743087            4                5         6          Clear
# 2               866418            4                5         6          Clear
# 3               775928            4                5         6          Clear
# 4               810128            4                5         6          Clear
# ...                ...          ...              ...       ...            ...
# 2003            740689            4                5         6          Clear
# 2004            734280            4                5         6          Clear
# 2005            781004            4                5         6          Clear
# 2006            744870            1                1         1  Nonresponsive
# 2007            791864            4                5         6          Clear
#
#       GCS
# 0      15
# ...

# %%
df_PatientHistory=pd.read_excel('/content/Cardiac_Outcomes.xlsx', sheet_name='PatientHistory')

# %%
df_PatientHistory
# Out:
#       inpatient_number  cerebrovascular_disease  dementia  \
# 0               857781                        0         0
# 1               743087                        0         0
# 2               866418                        0         0
# 3               775928                        0         0
# 4               810128                        0         0
# ...                ...                      ...       ...
# 2003            740689                        0         0
# 2004            734280                        0         0
# 2005            781004                        0         0
# 2006            744870                        0         0
# 2007            791864                        0         0
#
#       Chronic_obstructive_pulmonary_disease  connective_tissue_disease  \
# 0                                         1                          0
# 1                                         0                          0
# ...

# %%
df_Labs=pd.read_excel('/content/Cardiac_Outcomes.xlsx', sheet_name='Labs')

# %%
df_Labs
# Out:
#       inpatient_number  body_temperature  pulse  respiration  \
# 0               857781              36.7     87           19
# 1               743087              36.8     95           18
# 2               866418              36.5     98           18
# 3               775928              36.0     73           19
# 4               810128              35.0     88           19
# ...                ...               ...    ...          ...
# 2003            740689              36.1    117           22
# 2004            734280              36.3     70           21
# 2005            781004              36.8    113           19
# 2006            744870              36.4    134           19
# 2007            791864              36.3    100           19
#
#       systolic_blood_pressure  diastolic_blood_pressure         map  fio2  \
# 0                         102                        64   76.666667    33
# 1                         150                        70   96.666667    33
# ...

# %%
df_Demography=pd.read_excel('/content/Cardiac_Outcomes.xlsx', sheet_name='Demography')

# %%
df_Demography
# Out:
#       inpatient_number  gender  weight  height        BMI     occupation  \
# 0               857781    Male    50.0    1.64  18.590125  UrbanResident
# 1               743087  Female    51.0    1.63  19.195303  UrbanResident
# 2               866418    Male    70.0    1.70  24.221453         farmer
# 3               775928    Male    65.0    1.70  22.491349  UrbanResident
# 4               810128  Female    76.0    1.55  31.633715  UrbanResident
# ...                ...     ...     ...     ...        ...            ...
# 2003            740689  Female    35.0    1.50  15.555556         Others
# 2004            734280  Female    50.0    1.55  20.811655  UrbanResident
# 2005            781004    Male    75.0    1.70  25.951557  UrbanResident
# 2006            744870    Male    40.0    1.50  17.777778  UrbanResident
# 2007            791864  Female    45.0    1.55  18.730489  UrbanResident
#
#      ageCat
# 0     69-79
# 1     69-79
# 2     59-69
# 3     69-79
# 4     69-79
# ...

# %%
df_PatientPrecriptions=pd.read_excel('/content/Cardiac_Outcomes.xlsx', sheet_name='Patient_Precriptions')

# %%
df_PatientPrecriptions
# Out:
#        inpatient_number                                         Drug_name
# 0                857781                  sulfotanshinone sodium injection
# 1                857781                                 Furosemide tablet
# 2                857781                       Enoxaparin Sodium injection
# 3                857781  Meglumine Adenosine Cyclophosphate for injection
# 4                857781                              Furosemide injection
# ...                 ...                                               ...
# 15365            123456                              Furosemide injection
# 15366            678910                             Deslanoside injection
# 15367            678910                               Milrinone injection
# 15368            678910                              Furosemide injection
# 15369            678910  Meglumine Adenosine Cyclophosphate for injection
#
# [15370 rows x 2 columns]

# %%
#Question no.65 Which Admission Ward has maximum number of visits scheduled
df_hospitaldischarge.groupby('admission_ward')['visit_times'].sum()
# Out:
# admission_ward
# Cardiology     1703
# GeneralWard     279
# ICU              17
# Others          195
# Name: visit_times, dtype: int64

# %%
#Question no. 67 How many Unique patients were precribed each type of medication?
df_PatientPrecriptions.groupby('Drug_name').nunique()
# Out:
#                                                   inpatient_number
# Drug_name
# Aspirin enteric-coated tablet                                  958
# Atorvastatin calcium tablet                                    822
# Benazepril hydrochloride tablet                                434
# Clopidogrel Hydrogen Sulphate tablet                           401
# Deslanoside injection                                         1017
# Digoxin tablet                                                 999
# Dobutamine hydrochloride injection                              22
# Enoxaparin Sodium injection                                    113
# Furosemide injection                                          1720
# Furosemide tablet                                             1641
# Heparin Sodium injection                                       153
# Hydrochlorothiazide tablet                                     283
# Isoprenaline Hydrochloride injection                            30
# ...

# %%
# Question 72 What % of the dataset is male vs female?
df_patients=df_Demography['inpatient_number'].sum()
df_patients
# Out:
# 1601877066

# %%
df_patients_gender=df_Demography.groupby('gender')['inpatient_number'].sum()
df_patients_gender
# Out:
# gender
# Female    927314412
# Male      674562654
# Name: inpatient_number, dtype: int64

# %%
percentage=(df_patients_gender/df_patients)*100
percentage
# Out:
# gender
# Female    57.889237
# Male      42.110763
# Name: inpatient_number, dtype: float64
